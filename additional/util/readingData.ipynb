# %%
import os
import numpy as np
import pandas as pd
import xarray as xr

# %%
filename = "./ggcmi/AgMerra/hur_agmerra_1980-2010.nc4"
data = xr.open_dataset(filename)
data
# Out:
# <xarray.Dataset>
# Dimensions:  (lon: 720, lat: 360, time: 11323)
# Coordinates:
#   * lon      (lon) float64 -179.8 -179.2 -178.8 -178.2 ... 178.8 179.2 179.8
#   * lat      (lat) float64 89.75 89.25 88.75 88.25 ... -88.75 -89.25 -89.75
#   * time     (time) datetime64[ns] 1980-01-01T01:00:00 ... 2010-12-31T01:00:00
# Data variables:
#     hur      (time, lat, lon) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 1.6.2 (http://code.zmaw.de/p...
#     history:      Wed Dec 04 18:21:02 2013: cdo -z zip_5 -s div /home/buechne...
#     source:       AgMIP / Alex Ruane
#     Conventions:  CF-1.4
#     title:        AgMERRA Relative Humidity Average approximated by Average T...
#     center:       NASA GISS
#     comment:      AgMERRA dataset processed for ISI-MIP, netCDF4 (isimip@pik-...
#     CDO:          Climate Data Operators version 1.6.2 (http://code.zmaw.de/p...

# %%
filename = "./ggcmi/AgMerra/hurtmax_agmerra_1980-2010.nc4"
data = xr.open_dataset(filename)
data
# Out:
# <xarray.Dataset>
# Dimensions:  (lon: 720, lat: 360, time: 11323)
# Coordinates:
#   * lon      (lon) float64 -179.8 -179.2 -178.8 -178.2 ... 178.8 179.2 179.8
#   * lat      (lat) float64 89.75 89.25 88.75 88.25 ... -88.75 -89.25 -89.75
#   * time     (time) datetime64[ns] 1980-01-01T01:00:00 ... 2010-12-31T01:00:00
# Data variables:
#     hurtmax  (time, lat, lon) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 1.6.2 (http://code.zmaw.de/p...
#     history:      Wed Dec 04 18:21:02 2013: cdo -z zip_5 -s div /home/buechne...
#     source:       AgMIP / Alex Ruane
#     Conventions:  CF-1.4
#     title:        AgMERRA Relative Humidity at time of Maximum Temperature
#     center:       NASA GISS
#     comment:      AgMERRA dataset processed for ISI-MIP, netCDF4 (isimip@pik-...
#     CDO:          Climate Data Operators version 1.6.2 (http://code.zmaw.de/p...

# %%
filename = "./ggcmi/AgMerra/pr_agmerra_1980-2010.nc4"
data = xr.open_dataset(filename)
data
# Out:
# <xarray.Dataset>
# Dimensions:  (lon: 720, lat: 360, time: 11323)
# Coordinates:
#   * lon      (lon) float64 -179.8 -179.2 -178.8 -178.2 ... 178.8 179.2 179.8
#   * lat      (lat) float64 89.75 89.25 88.75 88.25 ... -88.75 -89.25 -89.75
#   * time     (time) datetime64[ns] 1980-01-01T01:00:00 ... 2010-12-31T01:00:00
# Data variables:
#     pr       (time, lat, lon) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 1.6.1 (http://code.zmaw.de/p...
#     history:      Wed Jul 10 11:55:27 2013: cdo -s remapcon,/home/buechner/is...
#     Conventions:  CF-1.4
#     title:        AgMERRA Precipitation Rate
#     center:       NASA GISS
#     comment:      AgMERRA dataset processed for ISI-MIP, netCDF4 (isimip@pik-...
#     CDO:          Climate Data Operators version 1.6.1 (http://code.zmaw.de/p...

# %%
filename = "./ggcmi/AgMerra/rsds_agmerra_1980-2010.nc4"
data = xr.open_dataset(filename)
data
# Out:
# <xarray.Dataset>
# Dimensions:  (lon: 720, lat: 360, time: 11323)
# Coordinates:
#   * lon      (lon) float64 -179.8 -179.2 -178.8 -178.2 ... 178.8 179.2 179.8
#   * lat      (lat) float64 89.75 89.25 88.75 88.25 ... -88.75 -89.25 -89.75
#   * time     (time) datetime64[ns] 1980-01-01T01:00:00 ... 2010-12-31T01:00:00
# Data variables:
#     rsds     (time, lat, lon) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 1.6.2 (http://code.zmaw.de/p...
#     history:      Wed Dec 04 18:21:03 2013: cdo -z zip_5 -s div /home/buechne...
#     Conventions:  CF-1.4
#     title:        AgMERRA Solar Radiation Flux
#     center:       NASA GISS
#     comment:      AgMERRA dataset processed for ISI-MIP, netCDF4 (isimip@pik-...
#     CDO:          Climate Data Operators version 1.6.2 (http://code.zmaw.de/p...

# %%
filename = "./ggcmi/AgMerra/tas_agmerra_1980-2010.nc4"
data = xr.open_dataset(filename)
data
# Out:
# <xarray.Dataset>
# Dimensions:  (lon: 720, lat: 360, time: 11323)
# Coordinates:
#   * lon      (lon) float64 -179.8 -179.2 -178.8 -178.2 ... 178.8 179.2 179.8
#   * lat      (lat) float64 89.75 89.25 88.75 88.25 ... -88.75 -89.25 -89.75
#   * time     (time) datetime64[ns] 1980-01-01T01:00:00 ... 2010-12-31T01:00:00
# Data variables:
#     tas      (time, lat, lon) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 1.6.2 (http://code.zmaw.de/p...
#     history:      Wed Dec 04 18:21:03 2013: cdo -z zip_5 -s div /home/buechne...
#     source:       AgMIP / Alex Ruane
#     Conventions:  CF-1.4
#     title:        AgMERRA Average Temperature
#     center:       NASA GISS
#     comment:      AgMERRA dataset processed for ISI-MIP, netCDF4 (isimip@pik-...
#     CDO:          Climate Data Operators version 1.6.2 (http://code.zmaw.de/p...

# %%
filename = "./ggcmi/AgMerra/tasmax_agmerra_1980-2010.nc4"
data = xr.open_dataset(filename)
data
# Out:
# <xarray.Dataset>
# Dimensions:  (lon: 720, lat: 360, time: 11323)
# Coordinates:
#   * lon      (lon) float64 -179.8 -179.2 -178.8 -178.2 ... 178.8 179.2 179.8
#   * lat      (lat) float64 89.75 89.25 88.75 88.25 ... -88.75 -89.25 -89.75
#   * time     (time) datetime64[ns] 1980-01-01T01:00:00 ... 2010-12-31T01:00:00
# Data variables:
#     tasmax   (time, lat, lon) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 1.6.2 (http://code.zmaw.de/p...
#     history:      Wed Dec 04 18:21:03 2013: cdo -z zip_5 -s div /home/buechne...
#     Conventions:  CF-1.4
#     title:        AgMERRA Maximum Temperature
#     center:       NASA GISS
#     comment:      AgMERRA dataset processed for ISI-MIP, netCDF4 (isimip@pik-...
#     CDO:          Climate Data Operators version 1.6.2 (http://code.zmaw.de/p...

# %%
filename = "./ggcmi/AgMerra/tasmin_agmerra_1980-2010.nc4"
data = xr.open_dataset(filename)
data
# Out:
# <xarray.Dataset>
# Dimensions:  (lon: 720, lat: 360, time: 11323)
# Coordinates:
#   * lon      (lon) float64 -179.8 -179.2 -178.8 -178.2 ... 178.8 179.2 179.8
#   * lat      (lat) float64 89.75 89.25 88.75 88.25 ... -88.75 -89.25 -89.75
#   * time     (time) datetime64[ns] 1980-01-01T01:00:00 ... 2010-12-31T01:00:00
# Data variables:
#     tasmin   (time, lat, lon) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 1.6.2 (http://code.zmaw.de/p...
#     history:      Wed Dec 04 18:21:02 2013: cdo -z zip_5 -s div /home/buechne...
#     source:       AgMIP / Alex Ruane
#     Conventions:  CF-1.4
#     title:        AgMERRA Minimum Temperature
#     center:       NASA GISS
#     comment:      AgMERRA dataset processed for ISI-MIP, netCDF4 (isimip@pik-...
#     CDO:          Climate Data Operators version 1.6.2 (http://code.zmaw.de/p...

# %%
filename = "./ggcmi/AgMerra/wind_agmerra_1980-2010.nc4"
data = xr.open_dataset(filename)
data
# Out:
# <xarray.Dataset>
# Dimensions:  (lon: 720, lat: 360, time: 11323)
# Coordinates:
#   * lon      (lon) float64 -179.8 -179.2 -178.8 -178.2 ... 178.8 179.2 179.8
#   * lat      (lat) float64 89.75 89.25 88.75 88.25 ... -88.75 -89.25 -89.75
#   * time     (time) datetime64[ns] 1980-01-01T01:00:00 ... 2010-12-31T01:00:00
# Data variables:
#     wind     (time, lat, lon) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 1.6.2 (http://code.zmaw.de/p...
#     history:      Wed Dec 04 18:21:03 2013: cdo -z zip_5 -s div /home/buechne...
#     Conventions:  CF-1.4
#     title:        AgMERRA Wind Speed
#     center:       NASA GISS
#     comment:      AgMERRA dataset processed for ISI-MIP, netCDF4 (isimip@pik-...
#     CDO:          Climate Data Operators version 1.6.2 (http://code.zmaw.de/p...

# %%
plantFile = "./ggcmi/phase2_outputs/A0/plant-day/pdssat_agmerra_fullharm_plant-day_mai_global_annual_1980_2010_C810_T6_W-20_N10_A0.nc4"
plantData = xr.open_dataset(plantFile, decode_times=False)
plantData
print(plantData.variables['plant-day_mai'])

# %%
matureFile = "./ggcmi/phase2_outputs/A0/maty-day/pdssat_agmerra_fullharm_maty-day_mai_global_annual_1980_2010_C810_T6_W-20_N10_A0.nc4"

matureData = xr.open_dataset(matureFile, decode_times=False)
matureData
print(matureData.variables['maty-day_mai'])

# %%
yieldFile = "./ggcmi/phase2_outputs/A0/yield/pdssat_agmerra_fullharm_yield_mai_global_annual_1980_2010_C360_T0_W-50_N60_A0.nc4"
yieldData = xr.open_dataset(yieldFile, decode_times=False)
yieldData
print(yieldData.variables['yield_mai'])
